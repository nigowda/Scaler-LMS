# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import binom

# %%
x_val=np.arange(0,11)
y_val=binom.pmf(n=10,k=x_val,p=0.5)
sns.barplot(x_val,y_val)
# Out:
# /Users/nikhilsanghi/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
x_val=np.arange(0,101)
y_val=binom.pmf(n=100,k=x_val,p=0.5)
sns.barplot(x_val,y_val)
# Out:
# /Users/nikhilsanghi/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
pd.value_counts(np.random.choice(["H","T"],size=10))
# Out:
# T    6
# H    4
# dtype: int64

# %%
pd.value_counts(np.random.choice(["H","T"],size=100))
# Out:
# T    51
# H    49
# dtype: int64

# %%
pd.value_counts(np.random.choice(["H","T"],size=1000))
# Out:
# H    514
# T    486
# dtype: int64

# %%
pd.value_counts(np.random.choice(["H","T"],size=10000))
# Out:
# H    5007
# T    4993
# dtype: int64

# %%
pd.value_counts(np.random.choice(["H","T"],size=100000))
# Out:
# T    50216
# H    49784
# dtype: int64

# %%
h_val=[]
for i in range(1000):
    size=100
    h_val.append(pd.value_counts(np.random.choice(["H","T"],size=size))["H"])
sns.kdeplot(h_val)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
h_val=[]
for i in range(1000):
    size=500
    h_val.append(pd.value_counts(np.random.choice(["H","T"],size=size))["H"])
sns.kdeplot(h_val)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
h_val=[]
for i in range(1000):
    size=1000
    h_val.append(pd.value_counts(np.random.choice(["H","T"],size=size))["H"])
sns.kdeplot(h_val)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
h_val=[]
for i in range(1000):
    size=10000
    h_val.append(pd.value_counts(np.random.choice(["H","T"],size=size))["H"]/size)
sns.kdeplot(h_val)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
h_val=[]
for i in range(1000):
    size=100000
    h_val.append(pd.value_counts(np.random.choice(["H","T"],size=size))["H"]/size)
sns.kdeplot(h_val)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
x_val=np.arange(0,11)
y_val=binom.pmf(n=10,k=x_val,p=0.5)
sns.barplot(x_val,y_val)
# Out:
# /Users/nikhilsanghi/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
1-binom.cdf(n=10,k=6,p=0.5)
# Out:
# 0.171875

# %%
binom.pmf(n=10,k=7,p=0.5)+binom.pmf(n=10,k=8,p=0.5)+binom.pmf(n=10,k=9,p=0.5)+binom.pmf(n=10,k=10,p=0.5)
# Out:
# 0.17187499999999994

# %%
1-binom.cdf(n=100,k=69,p=0.5)
# Out:
# 3.925069822796612e-05

# %%
1-binom.cdf(n=1000,k=699,p=0.5)
# Out:
# 0.0

# %%
import math
n=1000

# %%
math.comb(n,k)*(p**k)*((1-p)**n-k)
# Out:
# 45

# %%
val=[]
for i in range(700,1001):
    val.append(math.comb(n,k)*(p**i)*((1-p)**n-i))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/hd/9z4dczb56dj54lb7q8w7s4zw0000gn/T/ipykernel_55906/1007463631.py in <module>
#       1 val=[]
#       2 for i in range(700,1001):
# ----> 3     val.append(math.comb(n,k)*(p**k)*((1-p)**n-k))
#
# NameError: name 'n' is not defined

# %%
1-binom.cdf(n=1000,k=499,p=0.5)
# Out:
# 0.51261250908918

# %%
# Out:
# 0.025225018178360804

# %%
h_val=[]
for i in range(1000):
    size=1000
    h_val.append(pd.value_counts(np.random.choice(["H","T"],p=[0.7,0.3],size=size))["H"])
sns.kdeplot(h_val)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
pd.value_counts(np.random.choice(["H","T"],p=[0.7,0.3],size=1000))
# Out:
# H    679
# T    321
# dtype: int64

# %%
1-binom.cdf(n=1000,k=699,p=0.7)
# Out:
# 0.5155935198141187

# %%
h_val=[]
for i in range(1000):
    size=1000
    h_val.append(pd.value_counts(np.random.choice(["H","T"],p=[0.6,0.4],size=size))["H"])
sns.kdeplot(h_val)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
norm.cdf(x.loc.scale)
norm.ppf(.99)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/hd/9z4dczb56dj54lb7q8w7s4zw0000gn/T/ipykernel_55906/1647155091.py in <module>
# ----> 1 norm.cdf(x.loc.scale)
#
# NameError: name 'norm' is not defined
